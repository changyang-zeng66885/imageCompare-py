# %% [markdown]
# # 基于关键点检测的差异识别

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def moveDetectionByKeyPoints(imagePath1,imagePath2):
    # 读取图片
    image1 = cv2.imread(imagePath1)
    image2 = cv2.imread(imagePath2)

    # 将图片转换为灰度图
    gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

    # 初始化SIFT检测器
    sift = cv2.SIFT_create()

    # 检测关键点和计算描述子
    kp1, des1 = sift.detectAndCompute(gray1, None)
    kp2, des2 = sift.detectAndCompute(gray2, None)

    # 使用FLANN匹配器进行匹配
    FLANN_INDEX_KDTREE = 1
    index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
    search_params = dict(checks=50)

    flann = cv2.FlannBasedMatcher(index_params, search_params)
    matches = flann.knnMatch(des1, des2, k=2)

    # 使用Lowe's ratio test来筛选匹配点
    good_matches = []
    for m, n in matches:
        if m.distance < 0.7 * n.distance:
            good_matches.append(m)

    # 提取匹配点坐标
    points1 = np.float32([kp1[m.queryIdx].pt for m in good_matches]).reshape(-1, 1, 2)
    points2 = np.float32([kp2[m.trainIdx].pt for m in good_matches]).reshape(-1, 1, 2)

    # 计算单应性矩阵
    H, mask = cv2.findHomography(points1, points2, cv2.RANSAC, 5.0)
    matchesMask = mask.ravel().tolist()

    # 使用单应性矩阵对第一张图片进行透视变换
    # height, width, channels = image2.shape
    # im1_reg = cv2.warpPerspective(image1, H, (width, height))

    # 计算关键点位置的变化
    point_changes = []
    for i, match in enumerate(good_matches):
        if matchesMask[i]:
            pt1 = np.array(kp1[match.queryIdx].pt)
            pt2 = np.array(kp2[match.trainIdx].pt)
            point_changes.append((pt1, pt2, np.linalg.norm(pt1 - pt2)))

    # 定义绘制参数
    keypoint_size = 10
    line_thickness = 5

    # 在图片上绘制关键点和匹配线
    image1_with_kp = cv2.drawKeypoints(image1, kp1, None, color=(0, 255, 0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    image2_with_kp = cv2.drawKeypoints(image2, kp2, None, color=(0, 255, 0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

    # 绘制匹配线条
    for i, match in enumerate(good_matches):
        if matchesMask[i]:
            pt1 = tuple(np.round(kp1[match.queryIdx].pt).astype(int))
            pt2 = tuple(np.round(kp2[match.trainIdx].pt).astype(int) + np.array([image1.shape[1], 0]))
            cv2.circle(image1_with_kp, pt1, keypoint_size, (0, 0, 255), -1)
            cv2.circle(image2_with_kp, pt2 - np.array([image1.shape[1], 0]), keypoint_size, (0, 0, 255), -1)
            cv2.line(image2_with_kp, pt1, pt2 - np.array([image1.shape[1], 0]), (255, 0, 0), line_thickness)

    # 合并两张图片用于显示匹配
    combined_image = np.hstack((image1_with_kp, image2_with_kp))

    # 显示结果
    plt.figure(figsize=(20, 10))
    plt.title('Keypoints and Matches')
    plt.imshow(cv2.cvtColor(combined_image, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
imagePath1 = "images/image1.jpg"
imagePath2 = "images/image2.jpg"
moveDetectionByKeyPoints(imagePath1,imagePath2)

# %%
imagePath1 = "images/image1.jpg"
imagePath2 = "images/image3.jpg"
moveDetectionByKeyPoints(imagePath1,imagePath2)

# %%
imagePath1 = "images/image1.jpg"
imagePath2 = "images/image4.jpg"
moveDetectionByKeyPoints(imagePath1,imagePath2)

# %% [markdown]
# 图片1和图片4 的对比，两个姓名牌的位置差别过大，使用SIFT寻找关键点也不好找。
#
# 对应实际情况，假如观测文物（比如可移动的花瓶等）被人为移动，但是摄像头的位置不可能随便动，我们就要想办法将图像通过认为设定的关键点进行校正，校正之后再分析。

# %% [markdown]
# 我们是这样想的，姓名牌的四个角肯定是我们认为设定的关键点
#
# 我们的图像调整，要假设这4个关键点的相对位置不会发生变化。

# %%
# 转换为灰度图像
image1 = cv2.imread(imagePath1)

gray1 = cv2.cvtColor(image1, cv2.COLOR_RGB2GRAY)
# 进行边缘检测
edges = cv2.Canny(gray1, 100, 150)





plt.imshow(edges)

# # 寻找轮廓
# contours, _ = cv2.findContours(edges1, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# # 在原始图像上绘制轮廓
# image_with_contours = image.copy()
